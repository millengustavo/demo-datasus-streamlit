# %% [markdown]
# # Demo Application with DataSUS death records and Streamlit

# %% [markdown]
# ![datasus_app](../assets/datasus_app_pt.png)
#
# In Brazil, [more than 70% of the population depends exclusively on the medical assistance provided by the government](http://bvsms.saude.gov.br/bvs/pacsaude/diretrizes.php). The Brazilian public healthcare system is called SUS (Sistema Único de Saúde).
#
# Fortunately for us, there is a public SUS data repository available online (DataSUS). Although the data is not always clean and complete, we can derive many insights from DataSUS.
#
# In this post we are going to build and deploy a Streamlit application inspired on the [Uber pickups example](https://github.com/streamlit/demo-uber-nyc-pickups), but using DataSUS death records (2006-2017) and geographic coordinates from health facilities.

# %% [markdown]
# ## Downloading the data from DataSUS
#
# ### SIM
#
# From the [DataSUS website](http://www2.datasus.gov.br/DATASUS/index.php?area=060701) we have the definition of SIM:
# > The Mortality Information System (SIM) was created by DATASUS for the regular collection of mortality data in the country. From the creation of the SIM it was possible to comprehensively capture mortality data to subsidize the various management spheres in public health. Based on this information it is possible to perform situation analysis, planning and evaluation of actions and programs in the area.
#
# Let's download the SIM data for the São Paulo state. The prefixes of the files are "DOSP".
#
# #### Downloading the data from the ftp

# %%
from ftplib import FTP

ftp = FTP("ftp.datasus.gov.br")
ftp.login()
ftp.cwd("dissemin/publicos/SIM/CID10/DORES/")
all_files = ftp.nlst(".")
state_prefix = "DOSP"
# We sort the list and keep only the last 12 records
# This is because they share the same layout of the current data (2006-2017)
files = sorted([file for file in all_files if state_prefix in file])[-12:]

for file in files:
    print("Downloading {}...".format(file))
    with open("../data/SIM/" + file, "wb") as fp:
        ftp.retrbinary("RETR {}".format(file), fp.write)
# Out:
# Downloading DOSP2006.dbc...
# Downloading DOSP2007.DBC...
# Downloading DOSP2008.dbc...
# Downloading DOSP2009.dbc...
# Downloading DOSP2010.DBC...
# Downloading DOSP2011.DBC...
# Downloading DOSP2012.DBC...
# Downloading DOSP2013.dbc...
# Downloading DOSP2014.dbc...
# Downloading DOSP2015.dbc...
# Downloading DOSP2016.dbc...
# Downloading DOSP2017.dbc...

# %% [markdown]
# #### Renaming the files which the extension is capitalized

# %%
import os

files = [file for file in os.listdir("../data/SIM/") if "DOSP" in file and ".DBC" in file]

for file in files:
    os.rename("../data/SIM/" + file, "../data/SIM/" + file[:-4] + ".dbc")

# %% [markdown]
# #### Converting from .dbc to .csv
# As you may have noticed, the files are in a `.dbc` format. This is a proprietary format of the SUS Department of Informatics (DATASUS).
#
# A kind developer provided a [tool](https://github.com/greatjapa/dbc2csv) to convert files from `.dbc` to `.csv`. To use this tool we will need to have `git` and `docker` installed.
#
# ##### Build the docker image
# ```bash
# git clone https://github.com/greatjapa/dbc2csv.git
# cd dbc2csv
# docker build -t dbc2csv .
# ```
#
# ##### Convert the files
# 1. Navigate to the folder where you download the `.dbc` files. Copy the full path to the directory, you can get this path by running:
# ```bash
# pwd
# ```
# 2. Run:
# ```bash
# docker run -it -v <full_path_to_the_directory>:/usr/src/app/data dbc2csv make
# ```
# 3. A `/csv` folder will be populated with the converted files.
#
# ![dbc2csv](../assets/dbc2csv.png)
#
# ### CNES
# From their [website](http://cnes.datasus.gov.br/):
# > The National Register of Health Facilities (CNES) is a public document and official information system for registering information about all health facilities in the country, regardless of their legal nature or integration with the Unified Health System (SUS).
#
# The process to download the data is simpler this time, they are already in a `.zip` file you can download from this link:
#
# ftp://ftp.datasus.gov.br/cnes/BASE_DE_DADOS_CNES_201910.ZIP
#
# We are going to use only one `.csv` file from this data: `tbEstabelecimento201910.csv`
#
# ## Processing the data
#
# ### Reading the facilities table with pandas
#
# To be efficient, we will pass only the columns that matter to our application.

# %%
import pandas as pd

cnes = pd.read_csv(
    "../data/CNES/tbEstabelecimento201910.csv",
    sep=";",
    usecols=[
        "CO_CNES",
        "CO_CEP",
        "NO_FANTASIA",
        "NO_LOGRADOURO",
        "CO_ESTADO_GESTOR",
        "NU_LATITUDE",
        "NU_LONGITUDE",
    ],
)

# %% [markdown]
# ### Filtering the data for the São Paulo state.
# From the dictionary available on the DataSUS website we know that '35' is the code for São Paulo. For this application we are only going to keep this data

# %%
cnes = cnes[cnes["CO_ESTADO_GESTOR"]==35]

# %% [markdown]
# ### Merging with the death records
# My converted `.csv` SIM files are in a folder called sim_files, make sure you modify the path accordingly

# %%
files = sorted(os.listdir("../data/SIM/csv/"))

dfs = [
    pd.read_csv(
        "../data/SIM/csv/" + file,
        usecols=["NUMERODO", "DTOBITO", "HORAOBITO", "CODESTAB"],
        low_memory=False
    )
    for file in files
]
df = pd.concat(dfs)

# We will drop the null CODESTABs (data without CNES code)
df = df.dropna()

# %% [markdown]
# Before proceeding to fill the missing coordinates, join the CODESTAB with the CO_CNES, so we have fewer facilities to fill.

# %%
cnes = cnes.rename(columns={"CO_CNES": "CODESTAB"})
merged = df.merge(cnes, on="CODESTAB")

# Since we merged with the death records file, we have many duplicates, 
# let's drop it to see which facilities have coordinates missing
unique_merged = merged[
    ["CODESTAB", "CO_CEP", "NU_LATITUDE", "NU_LONGITUDE"]
].drop_duplicates()
# Filtering the data for only the records where the coordinates are missing
missing_coords = unique_merged[unique_merged["NU_LATITUDE"].isnull()]
# The CEP was automatically converted to int and we have lost the first zero digit.
# This line converts to string and pad with zero so we have a valid CEP
missing_coords["CO_CEP"] = (
    missing_coords["CO_CEP"].astype(str).apply(lambda x: x.zfill(8)))
# Out:
# /Users/millengustavo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# We have 697 CEPs without coordinates, let's try to fill them up.
#
# ## Enriching the data from DataSUS with latitude and longitude (cep_to_coords)
#
# The data we downloaded from DataSUS is not complete. Geographic coordinates of various health facilities are missing. While latitude and longitude are not present in all cases, we do have the Brazilian zip code (CEP) for some.
#
# A quick search on Google for converting from CEP to latitude and longitude has shown that we had some scripts that mixed R and Python to achieve this task.
#
# Investigating the scripts further, it became clear that it was simple and valuable to implement this in Python. So, I removed the dependency of R to achieve the same result with just Python (https://github.com/millengustavo/cep_to_coords).
#
# ### Install geocode from source
# ```bash
# git clone https://github.com/millengustavo/cep_to_coords.git
# cd cep_to_coords
# git checkout master
# pip install -e .
# ```
#
# The package usage is simple. Call the `cep_to_coords` function with a valid CEP string, it will search the correios API for an address, concatenate it with the city and country and hit an [API](http://photon.komoot.de/) to get the coordinates.
#
# If you find it useful, please leave a star on [Github](https://github.com/millengustavo/cep_to_coords). The project is still in its infancy, so it is a great opportunity to [contribute to your first open source project](https://medium.com/@austintackaberry/why-you-should-contribute-to-open-source-software-right-now-bec8bd83cfc0) adding features or refactoring the code!
#
# ### Fill the coordinates

# %%
from cep_to_coords.geocode import cep_to_coords

cep_column = "CO_CEP"

unique_ceps = missing_coords[cep_column].unique()
# cep_to_coords returns a [lat, lon] list if it finds the coordinates
# else it returns [NaN, NaN]
missing_coords["lat"] = float("nan")
missing_coords["lon"] = float("nan")
for ind, elem in enumerate(unique_ceps):
    try:
        coords = cep_to_coords(elem)
        missing_coords.loc[ind, "lat"] = coords[0]
        missing_coords.loc[ind, "lon"] = coords[1]
    except Exception as e:
        print(elem, coords, e)
    print("{}%...".format(ind * 100 / len(unique_ceps)))
# Out:
# /Users/millengustavo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/millengustavo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# Requesting coordinates from Estrada da Riviera São Paulo Brasil
# 0.0%...
# /Users/millengustavo/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Requesting coordinates from Avenida Alcântara Machado São Paulo Brasil
# 0.1594896331738437%...
# /Users/millengustavo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# Requesting coordinates from Rua dos Economiários Barretos Brasil
# 0.3189792663476874%...
# Requesting coordinates from Rua Melvin Jones Arujá Brasil
# 0.4784688995215311%...
# Requesting coordinates from Rua Braz Sanches Arriaga Birigüi Brasil
# 0.6379585326953748%...
# Requesting coordinates from Rua Estevão Fernandes São Paulo Brasil
# 0.7974481658692185%...
# Requesting coordinates from Avenida Santo Amaro São Paulo Brasil
# 0.9569377990430622%...
# 1.1164274322169059%...
# Requesting coordinates from Avenida Nossa Senhora do Sabará São Paulo Brasil
# 1.2759170653907497%...
# Requesting coordinates from Avenida Washington Luiz Presidente Prudente Brasil
# 1.4354066985645932%...
# Requesting coordinates from Avenida Santo Amaro São Paulo Brasil
# 1.594896331738437%...
# Requesting coordinates from Praça Alexandre Fleming Botucatu Brasil
# 1.7543859649122806%...
# Requesting coordinates from Rodovia Regis Bittencourt Taboão da Serra Brasil
# 1.9138755980861244%...
# Requesting coordinates from Avenida Brigadeiro Luís Antônio São Paulo Brasil
# 2.073365231259968%...
# 2.2328548644338118%...
# 2.3923444976076556%...
# 2.5518341307814993%...
# Requesting coordinates from Avenida José Odorizzi São Bernardo do Campo Brasil
# 2.7113237639553427%...
# 2.8708133971291865%...
# Requesting coordinates from Avenida Lucas Nogueira Garcez Jacareí Brasil
# 3.0303030303030303%...
# Requesting coordinates from Avenida Andrade Neves Campinas Brasil
# 3.189792663476874%...
# 3.349282296650718%...
# 3.508771929824561%...
# 3.668261562998405%...
# 3.827751196172249%...
# 3.9872408293460926%...
# Requesting coordinates from Praça Bernardino de Campos 184 Itapira Brasil
# 4.146730462519936%...
# Requesting coordinates from Rua João Leme do Prado Jundiaí Brasil
# 4.30622009569378%...
# Requesting coordinates from Rua Vilaça São José dos Campos Brasil
# 4.4657097288676235%...
# 4.625199362041467%...
# 4.784688995215311%...
# Requesting coordinates from Rua Doutor Baeta Neves São Bernardo do Campo Brasil
# 4.944178628389155%...
# Requesting coordinates from Avenida Paragüai Sorocaba Brasil
# 5.103668261562999%...
# Requesting coordinates from Avenida Lineu de Moura São José dos Campos Brasil
# 5.2631578947368425%...
# 5.422647527910685%...
# Requesting coordinates from Avenida Eduardo Castro Várzea Paulista Brasil
# 5.582137161084529%...
# 5.741626794258373%...
# 5.901116427432217%...
# Requesting coordinates from Rua Epitácio Pessoa Sertãozinho Brasil
# 6.0606060606060606%...
# 6.220095693779904%...
# Requesting coordinates from Rua Monsenhor Ezequias Galvão Itu Brasil
# 6.379585326953748%...
# Requesting coordinates from Rua Miguel Carlos São Paulo Brasil
# 6.539074960127592%...
# Requesting coordinates from Rua Coronel João Dias Guimarães Caçapava Brasil
# 6.698564593301436%...
# 6.8580542264752795%...
# 7.017543859649122%...
# Requesting coordinates from Rua Bernardino de Campos Campinas Brasil
# 7.177033492822966%...
# Requesting coordinates from Avenida Brasil Presidente Prudente Brasil
# 7.33652312599681%...
# Requesting coordinates from Rua Coronel Albino Presidente Prudente Brasil
# 7.496012759170654%...
# 7.655502392344498%...
# 7.814992025518341%...
# Requesting coordinates from Rua São João Tupã Brasil
# 7.974481658692185%...
# Requesting coordinates from Avenida dos Imarés São Paulo Brasil
# 8.133971291866029%...
# Requesting coordinates from Rua Blumenau São Paulo Brasil
# 8.293460925039872%...
# 8.452950558213717%...
# Requesting coordinates from Rua Laura Maiello Kook Sorocaba Brasil
# 8.61244019138756%...
# Requesting coordinates from Rua Tucuna São Paulo Brasil
# 8.771929824561404%...
# Requesting coordinates from Rua da Saudade São João da Boa Vista Brasil
# 8.931419457735247%...
# 9.090909090909092%...
# 9.250398724082935%...
# Requesting coordinates from Avenida Silvestre Pires de Freitas Guarulhos Brasil
# 9.409888357256778%...
# Requesting coordinates from Rua Espacial Santana de Parnaíba Brasil
# 9.569377990430622%...
# Requesting coordinates from Avenida Heitor Villa Lobos São José dos Campos Brasil
# 9.728867623604465%...
# Requesting coordinates from Rua Salvador Filardi Bauru Brasil
# 9.88835725677831%...
# Requesting coordinates from Avenida Independência Piracicaba Brasil
# 10.047846889952153%...
# Requesting coordinates from Avenida Lourenço Batistella Araras Brasil
# 10.207336523125997%...
# 10.36682615629984%...
# 10.526315789473685%...
# Requesting coordinates from Rua Joaquim Nunes Pereira Franco da Rocha Brasil
# list index out of range
# 'NoneType' object is not subscriptable
# 10.685805422647528%...
# 10.84529505582137%...
# Requesting coordinates from Avenida São Paulo Sorocaba Brasil
# 11.004784688995215%...
# Requesting coordinates from Avenida Ibirapuera São Paulo Brasil
# 11.164274322169058%...
# Requesting coordinates from Rua José Mari Taboão da Serra Brasil
# 11.323763955342903%...
# Requesting coordinates from Avenida Choso Misato Ourinhos Brasil
# 11.483253588516746%...
# Requesting coordinates from Rua Smith Vasconcelos 327 Assis Brasil
# 11.64274322169059%...
# Requesting coordinates from Rua 8 Rio Claro Brasil
# 11.802232854864434%...
# Requesting coordinates from Rua Prudente de Moraes Suzano Brasil
# 11.961722488038278%...
# 12.121212121212121%...
# Requesting coordinates from Rua Paes Leme Andradina Brasil
# 12.280701754385966%...
# Requesting coordinates from Rua Barão de Duprat São Paulo Brasil
# 12.440191387559809%...
# Requesting coordinates from Rua Paulino Botelho de Abreu Sampaio São Carlos Brasil
# 12.599681020733652%...
# 12.759170653907496%...
# 12.91866028708134%...
# Requesting coordinates from Rua Eduardo Prado Votorantim Brasil
# 13.078149920255184%...
# Requesting coordinates from Avenida 23 Barretos Brasil
# 13.237639553429027%...
# Requesting coordinates from Rua Gustavo Maciel Bauru Brasil
# 13.397129186602871%...
# 13.556618819776714%...
# Requesting coordinates from Rua Rio Branco Bauru Brasil
# 13.716108452950559%...
# Requesting coordinates from Rua Santa Maria São Bernardo do Campo Brasil
# 13.875598086124402%...
# Requesting coordinates from Rua Brasil São Bernardo do Campo Brasil
# 14.035087719298245%...
# Requesting coordinates from Rua dos Vianas São Bernardo do Campo Brasil
# 14.19457735247209%...
# Requesting coordinates from Rua Antônio Luiz Filho Mogi Guaçu Brasil
# 14.354066985645932%...
# 14.513556618819777%...
# 14.67304625199362%...
# 14.832535885167465%...
# Requesting coordinates from Rua M 9 Rio Claro Brasil
# 14.992025518341308%...
# 15.151515151515152%...
# Requesting coordinates from Praça Barão do Rio Branco São Vicente Brasil
# 15.311004784688995%...
# Requesting coordinates from Rua Ouvidor Portugal São Paulo Brasil
# 15.470494417862838%...
# Requesting coordinates from Rua Humaitá São Paulo Brasil
# 15.629984051036683%...
# Requesting coordinates from Estrada do DAE Cotia Brasil
# 15.789473684210526%...
# Requesting coordinates from Avenida Carolina de Abreu Paulino Itapevi Brasil
# 15.94896331738437%...
# Requesting coordinates from Rua Pedro Fioretti Osasco Brasil
# 16.108452950558213%...
# Requesting coordinates from Rua Coronel Agostinho da Fonseca São Paulo Brasil
# 16.267942583732058%...
# Requesting coordinates from Rua Emílio Kerche de Menezes Sorocaba Brasil
# 16.427432216905903%...
# Requesting coordinates from Rua Coronel Moreira Cesar Marília Brasil
# 16.586921850079744%...
# Requesting coordinates from Rua Doutor Próspero Cecilio Coimbra Marília Brasil
# 16.74641148325359%...
# Requesting coordinates from Rua das Palmeiras Guarulhos Brasil
# 16.905901116427433%...
# Requesting coordinates from Rua Ipiranga Mogi das Cruzes Brasil
# 17.065390749601274%...
# Requesting coordinates from Rua General Glicério Santo André Brasil
# 17.22488038277512%...
# Requesting coordinates from Avenida Pereira Barreto São Bernardo do Campo Brasil
# 17.384370015948964%...
# Requesting coordinates from Rua Luís Juliani São Paulo Brasil
# 17.54385964912281%...
# Requesting coordinates from Rua Espanha Cubatão Brasil
# 17.70334928229665%...
# Requesting coordinates from Rua Jerônimo Antônio Fiuza Sorocaba Brasil
# 17.862838915470494%...
# Requesting coordinates from Rua Santa Izabel São Roque Brasil
# 18.02232854864434%...
# Requesting coordinates from Rodovia Sargento Luciano Arnaldo Covolan Penápolis Brasil
# 18.181818181818183%...
# Requesting coordinates from Avenida Santa Casa Penápolis Brasil
# 18.341307814992025%...
# Requesting coordinates from Avenida Espanha Araraquara Brasil
# 18.50079744816587%...
# Requesting coordinates from Rua Vitorino de Carvalho São Paulo Brasil
# 18.660287081339714%...
# Requesting coordinates from Rua Almirante Silvado São Paulo Brasil
# 18.819776714513555%...
# Requesting coordinates from Rua Doutor Alceu de Campos Rodrigues São Paulo Brasil
# 18.9792663476874%...
# Requesting coordinates from Rua Engenheiro Oscar Americano São Paulo Brasil
# 19.138755980861244%...
# Requesting coordinates from Avenida Winston Churchill São Bernardo do Campo Brasil
# 19.29824561403509%...
# Requesting coordinates from Rua Regente Feijó São José do Rio Preto Brasil
# 19.45773524720893%...
# Requesting coordinates from Avenida Padre Vicente Melillo Osasco Brasil
# 19.617224880382775%...
# Requesting coordinates from Rua Padre Damaso Osasco Brasil
# 19.77671451355662%...
# Requesting coordinates from Rua Espírito Santo 277 São Caetano do Sul Brasil
# 19.936204146730464%...
# Requesting coordinates from Rua Vicente Sabella Bragança Paulista Brasil
# 20.095693779904305%...
# Requesting coordinates from Rua Quintino Bocaiúva Amparo Brasil
# 20.25518341307815%...
# Requesting coordinates from Rua Domingos Leme Guaratinguetá Brasil
# 20.414673046251995%...
# 20.574162679425836%...
# Requesting coordinates from Avenida Aristides Joaquim de Oliveira Pindamonhangaba Brasil
# 20.73365231259968%...
# Requesting coordinates from Rua João Pais 8 São Paulo Brasil
# 20.893141945773525%...
# Requesting coordinates from Rua Cabo José Teixeira São Paulo Brasil
# 21.05263157894737%...
# Requesting coordinates from Avenida Santa Catarina São Paulo Brasil
# 21.21212121212121%...
# 21.371610845295056%...
# 21.5311004784689%...
# Requesting coordinates from Rua Mandaguaris Tupã Brasil
# 21.69059011164274%...
# Requesting coordinates from Avenida Nova Cantareira São Paulo Brasil
# 21.850079744816586%...
# Requesting coordinates from Rua Coimbra São Paulo Brasil
# 22.00956937799043%...
# Requesting coordinates from Rua das Perobas São Paulo Brasil
# 22.169059011164276%...
# Requesting coordinates from Rua Conselheiro Oscar Rodrigues Alves Araçatuba Brasil
# 22.328548644338117%...
# Requesting coordinates from Rua Benedita Fernandes Araçatuba Brasil
# 22.48803827751196%...
# Requesting coordinates from Avenida do Taboão São Bernardo do Campo Brasil
# 22.647527910685806%...
# Requesting coordinates from Rua Antônio Carlos São Paulo Brasil
# 22.80701754385965%...
# Requesting coordinates from Avenida Professor Francisco Morato São Paulo Brasil
# 22.966507177033492%...
# Requesting coordinates from Rua Tamandaré São Paulo Brasil
# 23.125996810207337%...
# Requesting coordinates from Rua Arnaldo Vallardi Portilho São Paulo Brasil
# 23.28548644338118%...
# Requesting coordinates from Avenida dos Esportes Valinhos Brasil
# 23.444976076555022%...
# Requesting coordinates from Avenida João Ometto Santa Bárbara D'Oeste Brasil
# 23.604465709728867%...
# Requesting coordinates from Rua Ministro Gabriel de Rezende Passos São Paulo Brasil
# 23.76395534290271%...
# Requesting coordinates from Avenida Antônio Marques Figueira Suzano Brasil
# 23.923444976076556%...
# Requesting coordinates from Rua Edson São Paulo Brasil
# 24.082934609250398%...
# Requesting coordinates from Rua São Carlos do Pinhal São Paulo Brasil
# 24.242424242424242%...
# Requesting coordinates from Rua Joaquim Marra São Paulo Brasil
# 24.401913875598087%...
# Requesting coordinates from Estrada de Itapecerica São Paulo Brasil
# 24.56140350877193%...
# Requesting coordinates from Rua Doutor Antônio Bento São Paulo Brasil
# 24.720893141945773%...
# Requesting coordinates from Avenida Olavo Fontoura São Paulo Brasil
# 24.880382775119617%...
# Requesting coordinates from Rua Urucurana São Paulo Brasil
# 25.039872408293462%...
# Requesting coordinates from Rua Relíquia São Paulo Brasil
# 25.199362041467303%...
# Requesting coordinates from Avenida Juriti São Paulo Brasil
# 25.358851674641148%...
# Requesting coordinates from Rua Faustolo São Paulo Brasil
# 25.518341307814993%...
# Requesting coordinates from Rua Capitão Francisco Lipi São Paulo Brasil
# 25.677830940988837%...
# Requesting coordinates from Rua João Vagnotti Itaquaquecetuba Brasil
# 25.83732057416268%...
# Requesting coordinates from Rua Atanázio Soares Sorocaba Brasil
# 25.996810207336523%...
# Requesting coordinates from Rua do Osmio 699 Santa Bárbara D'Oeste Brasil
# 26.156299840510368%...
# 26.31578947368421%...
# Requesting coordinates from Rua Maestro João Balan São Paulo Brasil
# 26.475279106858054%...
# Requesting coordinates from Estrada Guavirutuba São Paulo Brasil
# 26.634768740031898%...
# Requesting coordinates from Rua Catarina Álvares São Paulo Brasil
# 26.794258373205743%...
# 26.953748006379584%...
# Requesting coordinates from Avenida São Paulo Praia Grande Brasil
# 27.11323763955343%...
# Requesting coordinates from Rua dos Vianas São Bernardo do Campo Brasil
# 27.272727272727273%...
# Requesting coordinates from Rua Duarte da Costa São Paulo Brasil
# 27.432216905901118%...
# Requesting coordinates from Rua João Lopes de Lima São Paulo Brasil
# 27.59170653907496%...
# Requesting coordinates from Rua Professor Máximo Ribeiro Nunes São Paulo Brasil
# 27.751196172248804%...
# 27.91068580542265%...
# Requesting coordinates from Avenida Engenheiro Francisco José Longo São José dos Campos Brasil
# 28.07017543859649%...
# 28.229665071770334%...
# Requesting coordinates from Avenida Conselheiro Carrão São Paulo Brasil
# 28.38915470494418%...
# Requesting coordinates from Avenida Eusébio Matoso São Paulo Brasil
# 28.548644338118024%...
# Requesting coordinates from Rua César Montagnana Ribeirão Preto Brasil
# 28.708133971291865%...
# 28.86762360446571%...
# Requesting coordinates from Estrada Kizaemon Takeuti Taboão da Serra Brasil
# 29.027113237639554%...
# Requesting coordinates from Rua Ananias Carmerindo Pires Taboão da Serra Brasil
# 29.1866028708134%...
# Requesting coordinates from Rua Doutor Cesário Mota Júnior São Paulo Brasil
# 29.34609250398724%...
# Requesting coordinates from Avenida Carlos Liviero São Paulo Brasil
# 29.505582137161085%...
# Requesting coordinates from Rua Guaramembé São Paulo Brasil
# 29.66507177033493%...
# Requesting coordinates from Rua Antônio Guedes Tavares Caçapava Brasil
# 29.82456140350877%...
# 29.984051036682615%...
# Requesting coordinates from Rua Luís Antônio Verney São Paulo Brasil
# 30.14354066985646%...
# Requesting coordinates from Avenida Sport Club Corinthians Paulista Osasco Brasil
# 30.303030303030305%...
# Requesting coordinates from Vila Academia da Força Aérea Pirassununga Brasil
# 30.462519936204146%...
# Requesting coordinates from Rua Saldanha Marinho Piracicaba Brasil
# 30.62200956937799%...
# 30.781499202551835%...
# Requesting coordinates from Avenida Sampaio Vidal Marília Brasil
# 30.940988835725676%...
# Requesting coordinates from Rua Irmã Serafina Campinas Brasil
# 31.10047846889952%...
# Requesting coordinates from Rua João Batista do Nascimento São José dos Campos Brasil
# 31.259968102073366%...
# Requesting coordinates from Praça Cândida Maria César Sawaya Giana São José dos Campos Brasil
# list index out of range
# 'NoneType' object is not subscriptable
# 31.41945773524721%...
# Requesting coordinates from Rua Amin Assad São José dos Campos Brasil
# 31.57894736842105%...
# Requesting coordinates from Rua Ari Barroso Osasco Brasil
# 31.738437001594896%...
# 31.89792663476874%...
# Requesting coordinates from Rua Barão do Rio Branco São Paulo Brasil
# 32.057416267942585%...
# Requesting coordinates from Rua Tomé de Souza São Paulo Brasil
# 32.21690590111643%...
# Requesting coordinates from Rua Planalto de Conquista São Paulo Brasil
# 32.37639553429027%...
# Requesting coordinates from Rua da Figueira São Paulo Brasil
# 32.535885167464116%...
# Requesting coordinates from Rua Brigadeiro Gavião Peixoto São Paulo Brasil
# 32.69537480063796%...
# Requesting coordinates from Avenida Barão de Itapura Campinas Brasil
# 32.854864433811805%...
# Requesting coordinates from Rua Pedro Gonçalves Indaiatuba Brasil
# 33.014354066985646%...
# 33.17384370015949%...
# Requesting coordinates from Rua Doutor Edilberto Luís Pereira da Silva Campinas Brasil
# 33.333333333333336%...
# Requesting coordinates from Avenida Emílio Ribas Guarulhos Brasil
# 33.49282296650718%...
# Requesting coordinates from Rua Tito São Paulo Brasil
# 33.65231259968102%...
# Requesting coordinates from Rua Joaquim Távora São Paulo Brasil
# 33.811802232854866%...
# Requesting coordinates from Rua Uratinga São Paulo Brasil
# 33.97129186602871%...
# Requesting coordinates from Avenida São Miguel São Paulo Brasil
# 34.13078149920255%...
# Requesting coordinates from Rua São Joaquim São Paulo Brasil
# 34.2902711323764%...
# Requesting coordinates from Avenida Cangaíba São Paulo Brasil
# 34.44976076555024%...
# 34.609250398724086%...
# Requesting coordinates from Rua José Jannarelli São Paulo Brasil
# 34.76874003189793%...
# Requesting coordinates from Rua Dona Adma Jafet São Paulo Brasil
# 34.92822966507177%...
# Requesting coordinates from Avenida Brigadeiro Faria Lima São Paulo Brasil
# 35.08771929824562%...
# Requesting coordinates from Avenida Raimundo Pereira de Magalhães São Paulo Brasil
# 35.24720893141946%...
# Requesting coordinates from Rua Quinze de Novembro São Vicente Brasil
# 35.4066985645933%...
# Requesting coordinates from Rua Mercedes Lopes São Paulo Brasil
# 35.56618819776715%...
# Requesting coordinates from Estrada dos Alvarengas São Bernardo do Campo Brasil
# 35.72567783094099%...
# 35.88516746411483%...
# Requesting coordinates from Avenida Professor Manoel José Pedroso Cotia Brasil
# 36.04465709728868%...
# Requesting coordinates from Rua Vicente de Carvalho Americana Brasil
# 36.20414673046252%...
# Requesting coordinates from Rua Primeiro de Maio Americana Brasil
# 36.36363636363637%...
# 36.52312599681021%...
# 36.68261562998405%...
# Requesting coordinates from Rua Oswaldo Cruz Indaiatuba Brasil
# 36.8421052631579%...
# Requesting coordinates from Rua Rangel Pestana 762 Piracicaba Brasil
# 37.00159489633174%...
# Requesting coordinates from Rua Padre Benedito de Camargo São Paulo Brasil
# 37.16108452950558%...
# 37.32057416267943%...
# 37.48006379585327%...
# Requesting coordinates from Avenida das Rosas São José dos Campos Brasil
# 37.63955342902711%...
# 37.79904306220096%...
# Requesting coordinates from Avenida Riusaku Kanizawa Sorocaba Brasil
# 37.9585326953748%...
# Requesting coordinates from Avenida Júlio Buono São Paulo Brasil
# 38.11802232854865%...
# Requesting coordinates from Avenida Dom Pedro I Campo Limpo Paulista Brasil
# 38.27751196172249%...
# Requesting coordinates from Rua Manoel da Nóbrega Diadema Brasil
# 38.43700159489633%...
# Requesting coordinates from Rua Tijuco Preto São Paulo Brasil
# 38.59649122807018%...
# Requesting coordinates from Rua Marcelina São Paulo Brasil
# 38.75598086124402%...
# Requesting coordinates from Rua Caculé São Paulo Brasil
# 38.91547049441786%...
# Requesting coordinates from Avenida Comendador Sant'Anna São Paulo Brasil
# 39.07496012759171%...
# Requesting coordinates from Rua Astarte São Paulo Brasil
# 39.23444976076555%...
# Requesting coordinates from Avenida Mateo Bei São Paulo Brasil
# 39.39393939393939%...
# Requesting coordinates from Avenida da Geraldo Campos Freire São Paulo Brasil
# 39.55342902711324%...
# Requesting coordinates from Rua do Lavapés São Paulo Brasil
# 39.71291866028708%...
# Requesting coordinates from Avenida Carlos de Campos São Paulo Brasil
# 39.87240829346093%...
# Requesting coordinates from Rua Eva Périco Rachid São Paulo Brasil
# 40.03189792663477%...
# Requesting coordinates from Rua Francisco Marengo São Paulo Brasil
# 40.19138755980861%...
# Requesting coordinates from Rua Lituânia São Paulo Brasil
# 40.35087719298246%...
# Requesting coordinates from Avenida Miruna São Paulo Brasil
# 40.5103668261563%...
# Requesting coordinates from Rua Coelho Neto Araçatuba Brasil
# 40.66985645933014%...
# Requesting coordinates from Rua Alfredo Mendes da Silva São Paulo Brasil
# 40.82934609250399%...
# Requesting coordinates from Avenida Utaro Kanai São Paulo Brasil
# 40.98883572567783%...
# Requesting coordinates from Rua Albino Demarchi São Bernardo do Campo Brasil
# 41.14832535885167%...
# Requesting coordinates from Rua Mourato Coelho São Paulo Brasil
# 41.30781499202552%...
# 41.46730462519936%...
# Requesting coordinates from Rua da Glória São Paulo Brasil
# 41.6267942583732%...
# Requesting coordinates from Avenida Brigadeiro Luís Antônio São Paulo Brasil
# 41.78628389154705%...
# 41.94577352472089%...
# Requesting coordinates from Avenida Marquês de Barbacena São Bernardo do Campo Brasil
# 42.10526315789474%...
# Requesting coordinates from Rua Doutor Humberto Campos Andradina Brasil
# 42.26475279106858%...
# Requesting coordinates from Avenida Conselheiro Rodrigues Alves São Paulo Brasil
# 42.42424242424242%...
# Requesting coordinates from Rua Nunes Siqueira São Paulo Brasil
# 42.58373205741627%...
# Requesting coordinates from Avenida Zaki Narchi São Paulo Brasil
# 42.74322169059011%...
# Requesting coordinates from Rua Silveira Pires São Paulo Brasil
# 42.90271132376395%...
# Requesting coordinates from Rua São João Guarujá Brasil
# 43.0622009569378%...
# Requesting coordinates from Rua Rolando Curti São Paulo Brasil
# 43.22169059011164%...
# Requesting coordinates from Rua Guilherme Asbahr Neto São Paulo Brasil
# 43.38118022328548%...
# Requesting coordinates from Avenida Amadeu da Silva Samelo São Paulo Brasil
# 43.54066985645933%...
# Requesting coordinates from Avenida Goiás São Caetano do Sul Brasil
# 43.70015948963317%...
# Requesting coordinates from Avenida Dom José Gaspar Mauá Brasil
# 43.85964912280702%...
# Requesting coordinates from Rua Nicoló Tartáglia São Paulo Brasil
# 44.01913875598086%...
# Requesting coordinates from Rua Laguna São Paulo Brasil
# 44.1786283891547%...
# 44.33811802232855%...
# Requesting coordinates from Rua Professor Giuliani São Paulo Brasil
# 44.49760765550239%...
# Requesting coordinates from Rua Dona Germaine Burchard São Paulo Brasil
# 44.65709728867623%...
# Requesting coordinates from Rua Pelotas São Paulo Brasil
# 44.81658692185008%...
# Requesting coordinates from Rua Alexander Flemming Campinas Brasil
# 44.97607655502392%...
# Requesting coordinates from Avenida Robert Kennedy São Bernardo do Campo Brasil
# 45.135566188197764%...
# Requesting coordinates from Rua Minas Gerais Andradina Brasil
# 45.29505582137161%...
# Requesting coordinates from Avenida São Miguel São Paulo Brasil
# 45.45454545454545%...
# 45.6140350877193%...
# Requesting coordinates from Rua Ernesto Soares Filho São Paulo Brasil
# 45.77352472089314%...
# Requesting coordinates from Avenida Santo Amaro São Paulo Brasil
# 45.933014354066984%...
# Requesting coordinates from Rua Alcântara Machado Francisco Morato Brasil
# 46.09250398724083%...
# Requesting coordinates from Rua Joaquim Nunes Itapevi Brasil
# 46.25199362041467%...
# Requesting coordinates from Praça Dom Pedro II Indaiatuba Brasil
# 46.411483253588514%...
# Requesting coordinates from Rua Joaquim Floriano São Paulo Brasil
# 46.57097288676236%...
# Requesting coordinates from Rua Vicente Aletto Mauá Brasil
# 46.730462519936204%...
# Requesting coordinates from Avenida Angélica São Paulo Brasil
# 46.889952153110045%...
# Requesting coordinates from Rua Francisco Lotufo São Paulo Brasil
# 47.04944178628389%...
# 47.208931419457734%...
# Requesting coordinates from Avenida Presidente Kennedy 9000 Praia Grande Brasil
# 47.36842105263158%...
# Requesting coordinates from Rua Rui Barbosa Ribeirão Preto Brasil
# 47.52791068580542%...
# Requesting coordinates from Rua Quinto Bertoldi 40 Guarujá Brasil
# 47.687400318979265%...
# Requesting coordinates from Rua Miragaia São Bernardo do Campo Brasil
# 47.84688995215311%...
# 48.006379585326954%...
# Requesting coordinates from Rua Pedro de Toledo São Paulo Brasil
# 48.165869218500795%...
# Requesting coordinates from Rua Júpiter São Paulo Brasil
# 48.32535885167464%...
# Requesting coordinates from Rua Rei Alberto da Bélgica São Paulo Brasil
# 48.484848484848484%...
# Requesting coordinates from Rua Tantas Palavras São Paulo Brasil
# 48.644338118022326%...
# Requesting coordinates from Rua José da Costa Gavião São Paulo Brasil
# 48.803827751196174%...
# Requesting coordinates from Avenida do Vaticano São Paulo Brasil
# 48.963317384370015%...
# Requesting coordinates from Rua das Pleiades São Paulo Brasil
# 49.12280701754386%...
# Requesting coordinates from Rua Itajuibe São Paulo Brasil
# 49.282296650717704%...
# Requesting coordinates from Rua Ângelo Aparecido dos Santos Dias São Paulo Brasil
# 49.441786283891545%...
# Requesting coordinates from Rua Batista Fergusio São Paulo Brasil
# 49.601275917065394%...
# Requesting coordinates from Avenida do Anastácio São Paulo Brasil
# 49.760765550239235%...
# Requesting coordinates from Rua das Olarias São Paulo Brasil
# 49.920255183413076%...
# Requesting coordinates from Rua Marcela Alves de Cássia São Paulo Brasil
# 50.079744816586924%...
# Requesting coordinates from Rua Albará São Paulo Brasil
# 50.239234449760765%...
# Requesting coordinates from Avenida Pompéia São Paulo Brasil
# 50.398724082934606%...
# Requesting coordinates from Avenida Jaime Torres São Paulo Brasil
# 50.558213716108455%...
# Requesting coordinates from Rua Rainha das Missões São Paulo Brasil
# 50.717703349282296%...
# Requesting coordinates from Avenida Engenheiro Armando de Arruda Pereira São Paulo Brasil
# 50.87719298245614%...
# Requesting coordinates from Rua Alvinópolis São Paulo Brasil
# 51.036682615629985%...
# Requesting coordinates from Rua Antônio Cajano São Paulo Brasil
# 51.196172248803826%...
# Requesting coordinates from Rua Tamandaré São Paulo Brasil
# 51.355661881977674%...
# Requesting coordinates from Rua Pedro de Toledo São Paulo Brasil
# 51.515151515151516%...
# Requesting coordinates from Praça Coronel Sandoval de Figueiredo São Paulo Brasil
# 51.67464114832536%...
# Requesting coordinates from Rua Bom Pastor São Paulo Brasil
# 51.834130781499205%...
# Requesting coordinates from Rua João Ventura Batista São Paulo Brasil
# 51.993620414673046%...
# Requesting coordinates from Travessa Somos Todos Iguais São Paulo Brasil
# 52.15311004784689%...
# Requesting coordinates from Avenida Menotti Laudisio São Paulo Brasil
# 52.312599681020735%...
# Requesting coordinates from Rua Barão de Paiva Manso São Paulo Brasil
# 52.47208931419458%...
# Requesting coordinates from Estrada das Taipas São Paulo Brasil
# 52.63157894736842%...
# Requesting coordinates from Rua Breno Acioli São Paulo Brasil
# 52.791068580542266%...
# Requesting coordinates from Rua François Bunel São Paulo Brasil
# 52.95055821371611%...
# Requesting coordinates from Rua Cadernos de Viagem São Paulo Brasil
# 53.110047846889955%...
# Requesting coordinates from Rua Abrão Calil Rezek São Paulo Brasil
# 53.269537480063796%...
# Requesting coordinates from Praça Nossa Senhora da Penha São Paulo Brasil
# 53.42902711323764%...
# Requesting coordinates from Rua Kumaki Aoki São Paulo Brasil
# 53.588516746411486%...
# Requesting coordinates from Rua Dinar São Paulo Brasil
# 53.74800637958533%...
# Requesting coordinates from Avenida Olavo Egídio de Souza Aranha São Paulo Brasil
# 53.90749601275917%...
# Requesting coordinates from Rua Salatiel de Campos São Paulo Brasil
# 54.066985645933016%...
# Requesting coordinates from Rua Manuel Teodoro Xavier São Paulo Brasil
# 54.22647527910686%...
# Requesting coordinates from Rua São Roque do Paraguaçu São Paulo Brasil
# 54.3859649122807%...
# Requesting coordinates from Rua Manuel Bordalo Pinheiro São Paulo Brasil
# 54.54545454545455%...
# Requesting coordinates from Avenida Amador Bueno da Veiga São Paulo Brasil
# 54.70494417862839%...
# Requesting coordinates from Rua Paulo César São Paulo Brasil
# 54.864433811802236%...
# Requesting coordinates from Rua Rio Grande do Sul Sorocaba Brasil
# 55.02392344497608%...
# 55.18341307814992%...
# Requesting coordinates from Rua Coronel João de Oliveira Melo São Paulo Brasil
# 55.34290271132377%...
# Requesting coordinates from Avenida Penha de França São Paulo Brasil
# 55.50239234449761%...
# 55.66188197767145%...
# 55.8213716108453%...
# Requesting coordinates from Avenida Dom Pedro I São Paulo Brasil
# 55.98086124401914%...
# Requesting coordinates from Rua Ana Neri Campinas Brasil
# 56.14035087719298%...
# Requesting coordinates from Avenida Leôncio de Magalhães São Paulo Brasil
# 56.29984051036683%...
# Requesting coordinates from Rua Marte Diadema Brasil
# 56.45933014354067%...
# Requesting coordinates from Rua José da Cruz Camargo São Paulo Brasil
# 56.61881977671452%...
# Requesting coordinates from Rua Daniel Klein São Paulo Brasil
# 56.77830940988836%...
# Requesting coordinates from Praça Vigário João Gonçalves de Lima São Paulo Brasil
# 56.9377990430622%...
# Requesting coordinates from Rua dos Aniquis São Paulo Brasil
# 57.09728867623605%...
# Requesting coordinates from Avenida Santo Afonso São Paulo Brasil
# 57.25677830940989%...
# Requesting coordinates from Avenida Doutor Francisco Munhoz Filho São Paulo Brasil
# 57.41626794258373%...
# Requesting coordinates from Rua Iapu Carapicuíba Brasil
# 57.57575757575758%...
# Requesting coordinates from Rua Catarina Gabrielli São Paulo Brasil
# 57.73524720893142%...
# Requesting coordinates from Avenida São Vicente de Paulo Catanduva Brasil
# 57.89473684210526%...
# 58.05422647527911%...
# Requesting coordinates from Avenida Possidonio José de Freitas São José dos Campos Brasil
# 58.21371610845295%...
# Requesting coordinates from Rua Engenheiro Prudente Meireles de Morais São José dos Campos Brasil
# 58.3732057416268%...
# Requesting coordinates from Rua Eurico Sodré São Paulo Brasil
# 58.53269537480064%...
# Requesting coordinates from Avenida Santo Amaro São Paulo Brasil
# 58.69218500797448%...
# Requesting coordinates from Avenida Pompéia São Paulo Brasil
# 58.85167464114833%...
# Requesting coordinates from Rua Luís Vives São Paulo Brasil
# 59.01116427432217%...
# Requesting coordinates from Rua Adauto Bezerra Delgado São Paulo Brasil
# 59.17065390749601%...
# Requesting coordinates from Rua Riachuelo Pirajuí Brasil
# 59.33014354066986%...
# Requesting coordinates from Rua Maracaí Catanduva Brasil
# 59.4896331738437%...
# Requesting coordinates from Avenida Ana Costa Santos Brasil
# 59.64912280701754%...
# Requesting coordinates from Avenida Presidente Wilson São Vicente Brasil
# 59.80861244019139%...
# Requesting coordinates from Avenida Osvaldo Valle Cordeiro São Paulo Brasil
# 59.96810207336523%...
# Requesting coordinates from Rua Augusto Correa Leite São Paulo Brasil
# 60.12759170653907%...
# Requesting coordinates from Rua Thereza Maia Pinto São Paulo Brasil
# 60.28708133971292%...
# Requesting coordinates from Rua João Fialho de Carvalho São Paulo Brasil
# 60.44657097288676%...
# Requesting coordinates from Rua Apucarana São Paulo Brasil
# 60.60606060606061%...
# Requesting coordinates from Rua Luís Asson São Paulo Brasil
# 60.76555023923445%...
# Requesting coordinates from Praça Camilo Castelo Branco São Paulo Brasil
# 60.92503987240829%...
# Requesting coordinates from Rua Voluntários da Pátria São Paulo Brasil
# 61.08452950558214%...
# Requesting coordinates from Rua Orlando Ribeiro Dantas São Paulo Brasil
# 61.24401913875598%...
# Requesting coordinates from Rua Valorbe São Paulo Brasil
# 61.40350877192982%...
# Requesting coordinates from Rua Oscar de Moura Lacerda São Paulo Brasil
# 61.56299840510367%...
# Requesting coordinates from Rua Vicente da Costa São Paulo Brasil
# 61.72248803827751%...
# Requesting coordinates from Rua Agnaldo José dos Santos Itapevi Brasil
# 61.88197767145135%...
# Requesting coordinates from Rua Barão de Iguape São Paulo Brasil
# 62.0414673046252%...
# Requesting coordinates from Rua Uriel Gaspar São Paulo Brasil
# 62.20095693779904%...
# Requesting coordinates from Rua Arlindo Colaço São Paulo Brasil
# 62.36044657097289%...
# Requesting coordinates from Rua Francisco Peixoto Bizerra São Paulo Brasil
# 62.51993620414673%...
# Requesting coordinates from Rodovia João Amaral Gurgel Caçapava Brasil
# 62.67942583732057%...
# Requesting coordinates from Rua Professor Filadelfo Azevedo São Paulo Brasil
# 62.83891547049442%...
# 62.99840510366826%...
# 63.1578947368421%...
# 63.31738437001595%...
# Requesting coordinates from Rua Professor Nelson de Senna São Paulo Brasil
# 63.47687400318979%...
# Requesting coordinates from Avenida Doutor Bernardino de Campos Santos Brasil
# 63.63636363636363%...
# Requesting coordinates from Rua Boa Vista Itapecerica da Serra Brasil
# 63.79585326953748%...
# 63.95534290271132%...
# Requesting coordinates from Rua Benedicto Franco Presidente Prudente Brasil
# 64.11483253588517%...
# Requesting coordinates from Rua 5 Jales Brasil
# 64.274322169059%...
# Requesting coordinates from Avenida Armando Salles de Oliveira Suzano Brasil
# 64.43381180223285%...
# Requesting coordinates from Rua Cônego Nery Campinas Brasil
# 64.5933014354067%...
# Requesting coordinates from Rua Pedro de Castro Velho São Paulo Brasil
# 64.75279106858054%...
# Requesting coordinates from Rua Voluntários da Pátria São Paulo Brasil
# 64.91228070175438%...
# Requesting coordinates from Avenida João Paulo Barreto São Paulo Brasil
# 65.07177033492823%...
# Requesting coordinates from Rua Colorado do Oeste São Paulo Brasil
# 65.23125996810208%...
# Requesting coordinates from Rua Professor Antônio Prudente São Paulo Brasil
# 65.39074960127591%...
# Requesting coordinates from Rua Tirana São Paulo Brasil
# 65.55023923444976%...
# Requesting coordinates from Rua Cardoso de Almeida São Paulo Brasil
# 65.70972886762361%...
# Requesting coordinates from Rua dos Três Irmãos São Paulo Brasil
# 65.86921850079744%...
# Requesting coordinates from Rua Catumbi São Paulo Brasil
# 66.02870813397129%...
# Requesting coordinates from Rua Antônio Gil São Paulo Brasil
# 66.18819776714514%...
# Requesting coordinates from Avenida Professor Osvaldo de Oliveira São Paulo Brasil
# 66.34768740031897%...
# Requesting coordinates from Rua Francisco Cardoso Júnior São Paulo Brasil
# 66.50717703349282%...
# Requesting coordinates from Rua Serra de Jairé São Paulo Brasil
# 66.66666666666667%...
# Requesting coordinates from Rua Giovanni Di Balduccio São Paulo Brasil
# 66.8261562998405%...
# Requesting coordinates from Rua Doutor Osmar Marinho Couto Mogi das Cruzes Brasil
# 66.98564593301435%...
# Requesting coordinates from Rua Antônio Soares Lara São Paulo Brasil
# 67.1451355661882%...
# Requesting coordinates from Rua dos Buritis São Paulo Brasil
# 67.30462519936204%...
# Requesting coordinates from Rua Ytaipu São Paulo Brasil
# 67.46411483253588%...
# Requesting coordinates from Rua Costeira São Paulo Brasil
# 67.62360446570973%...
# Requesting coordinates from Rua Engenheiro Teixeira Soares São Paulo Brasil
# 67.78309409888357%...
# Requesting coordinates from Rua Doutor Ramiro de Araújo Filho Jundiaí Brasil
# 67.94258373205741%...
# Requesting coordinates from Avenida Barueri Carapicuíba Brasil
# 68.10207336523126%...
# Requesting coordinates from Avenida Doutor Hermínio Ometto Leme Brasil
# 68.2615629984051%...
# Requesting coordinates from Rua Rio Manuel Alves São Paulo Brasil
# 68.42105263157895%...
# Requesting coordinates from Rua Encruzilhada do Sul São Paulo Brasil
# 68.5805422647528%...
# Requesting coordinates from Rua Belém Santos São Paulo Brasil
# 68.74003189792664%...
# Requesting coordinates from Avenida do Taboão 899 São Bernardo do Campo Brasil
# 68.89952153110048%...
# Requesting coordinates from Rua Timor São Bernardo do Campo Brasil
# 69.05901116427432%...
# Requesting coordinates from Rua Júlio Mesquita Araras Brasil
# 69.21850079744817%...
# Requesting coordinates from Rua Botafogo Praia Grande Brasil
# 69.377990430622%...
# Requesting coordinates from Rua Conselheiro Brotero São Paulo Brasil
# 69.53748006379585%...
# Requesting coordinates from Rua Voluntários da Pátria São Paulo Brasil
# 69.6969696969697%...
# Requesting coordinates from Avenida Água Fria São Paulo Brasil
# 69.85645933014354%...
# Requesting coordinates from Avenida Francisco Prestes Maia São Bernardo do Campo Brasil
# 70.01594896331738%...
# Requesting coordinates from Rua Itapeva São Paulo Brasil
# 70.17543859649123%...
# Requesting coordinates from Rua Aurélia Salazar Jorge São Bernardo do Campo Brasil
# 70.33492822966507%...
# Requesting coordinates from Rua Álvaro Leão Carmelo Guarujá Brasil
# 70.49441786283892%...
# Requesting coordinates from Praça Marechal Deodoro São Paulo Brasil
# 70.65390749601276%...
# Requesting coordinates from Rua Azevedo Soares São Paulo Brasil
# 70.8133971291866%...
# Requesting coordinates from Praça Floriano Peixoto São Paulo Brasil
# 70.97288676236045%...
# Requesting coordinates from Avenida Bento Guelfi São Paulo Brasil
# 71.1323763955343%...
# Requesting coordinates from Rua Demétrio Calfat Cotia Brasil
# 71.29186602870813%...
# Requesting coordinates from Avenida Padre Francisco de Toledo São Paulo Brasil
# 71.45135566188198%...
# Requesting coordinates from Rua Afonso Pedrazzi Sorocaba Brasil
# 71.61084529505582%...
# Requesting coordinates from Rua João Otávio Santos Brasil
# 71.77033492822966%...
# Requesting coordinates from Rua Edward Scarabucci Teixeira Franca Brasil
# 71.9298245614035%...
# Requesting coordinates from Rua Padre Anchieta Americana Brasil
# 72.08931419457736%...
# Requesting coordinates from Rua Frederico Moura Franca Brasil
# 72.2488038277512%...
# Requesting coordinates from Rua Doutor Olyntho Rodrigues Dantas Santos Brasil
# 72.40829346092504%...
# Requesting coordinates from Rua Luiz Vaz de Camões São Carlos Brasil
# 72.56778309409889%...
# Requesting coordinates from Rua Alexandre Dumas São Paulo Brasil
# 72.72727272727273%...
# Requesting coordinates from Rua Cachoeira da Ilha São Paulo Brasil
# 72.88676236044657%...
# Requesting coordinates from Rua Diego Velasquez São Paulo Brasil
# 73.04625199362042%...
# Requesting coordinates from Avenida João XXIII São Paulo Brasil
# 73.20574162679426%...
# Requesting coordinates from Avenida Nove de Julho São Paulo Brasil
# 73.3652312599681%...
# Requesting coordinates from Rua Maestro Cardim São Paulo Brasil
# 73.52472089314195%...
# Requesting coordinates from Rua Pedro Ravara São Paulo Brasil
# 73.6842105263158%...
# Requesting coordinates from Rua Sílvio Barbini São Paulo Brasil
# 73.84370015948963%...
# Requesting coordinates from Rua Vergueiro São Paulo Brasil
# 74.00318979266348%...
# Requesting coordinates from Rua Eunice Ferraz Fernandes Bragança Paulista Brasil
# 74.16267942583733%...
# 74.32216905901116%...
# 74.48165869218501%...
# Requesting coordinates from Rua General Chagas Santos São Paulo Brasil
# 74.64114832535886%...
# Requesting coordinates from Rua Benedito Schunck São Paulo Brasil
# 74.80063795853269%...
# 74.96012759170654%...
# Requesting coordinates from Avenida General Ataliba Leonel São Paulo Brasil
# 75.11961722488039%...
# Requesting coordinates from Avenida Governador Jânio Quadros Ferraz de Vasconcelos Brasil
# 75.27910685805422%...
# Requesting coordinates from Rua Lourenço Prado Jaú Brasil
# 75.43859649122807%...
# Requesting coordinates from Avenida Doutor Adhemar de Barros São José dos Campos Brasil
# 75.59808612440192%...
# Requesting coordinates from Rua Emboaçava São Paulo Brasil
# 75.75757575757575%...
# Requesting coordinates from Rua Conselheiro Saraiva São Paulo Brasil
# 75.9170653907496%...
# Requesting coordinates from Avenida Itaberaba São Paulo Brasil
# 76.07655502392345%...
# Requesting coordinates from Avenida Pompéia São Paulo Brasil
# 76.2360446570973%...
# Requesting coordinates from Rua Japani São Paulo Brasil
# 76.39553429027113%...
# Requesting coordinates from Rua Doutor Jaci Barbosa São Paulo Brasil
# 76.55502392344498%...
# Requesting coordinates from Rua Ibiajara São Paulo Brasil
# 76.71451355661883%...
# Requesting coordinates from Rua Miguel Ferreira de Melo São Paulo Brasil
# 76.87400318979266%...
# Requesting coordinates from Rua Padre Adelino 758 São Paulo Brasil
# 77.03349282296651%...
# Requesting coordinates from Avenida Indianópolis São Paulo Brasil
# 77.19298245614036%...
# Requesting coordinates from Rua Cristiano Viana São Paulo Brasil
# 77.35247208931419%...
# Requesting coordinates from Rua Martiniano de Carvalho São Paulo Brasil
# 77.51196172248804%...
# Requesting coordinates from Avenida Vasco Massafeli Cotia Brasil
# 77.67145135566189%...
# Requesting coordinates from Rua Juraci Cardeli Lomas Hortolândia Brasil
# 77.83094098883572%...
# Requesting coordinates from Rua Sebastião Ferreira dos Santos Itaquaquecetuba Brasil
# 77.99043062200957%...
# 78.14992025518342%...
# Requesting coordinates from Rua Pedro Malazartes Taubaté Brasil
# 78.30940988835725%...
# 78.4688995215311%...
# Requesting coordinates from Rua Doutor Edson de Melo São Paulo Brasil
# 78.62838915470495%...
# Requesting coordinates from Rua Piranema São Paulo Brasil
# 78.78787878787878%...
# Requesting coordinates from Rua Pedro de Toledo São Paulo Brasil
# 78.94736842105263%...
# Requesting coordinates from Avenida Doutor Arnaldo 455 São Paulo Brasil
# 79.10685805422648%...
# Requesting coordinates from Rua Conselheiro Brotero São Paulo Brasil
# 79.26634768740031%...
# Requesting coordinates from Rua Doutor Luís Lustosa da Silva São Paulo Brasil
# 79.42583732057416%...
# Requesting coordinates from Rua dos Morás São Paulo Brasil
# 79.58532695374801%...
# Requesting coordinates from Avenida Doutor Eduardo Cotching São Paulo Brasil
# 79.74481658692186%...
# Requesting coordinates from Rua São José das Espinharas São Paulo Brasil
# 79.90430622009569%...
# Requesting coordinates from Avenida Santo Amaro São Paulo Brasil
# 80.06379585326954%...
# Requesting coordinates from Rua Vicente Jorge São Paulo Brasil
# 80.22328548644339%...
# Requesting coordinates from Avenida Sabiá São Paulo Brasil
# 80.38277511961722%...
# Requesting coordinates from Rua Pistóia São Paulo Brasil
# 80.54226475279107%...
# Requesting coordinates from Avenida Brasil São Paulo Brasil
# 80.70175438596492%...
# Requesting coordinates from Rua Manuel França dos Santos São Paulo Brasil
# 80.86124401913875%...
# Requesting coordinates from Rua Peixoto Gomide 625 São Paulo Brasil
# 81.0207336523126%...
# Requesting coordinates from Praça Nabek Shiroma Sorocaba Brasil
# 81.18022328548645%...
# Requesting coordinates from Rua João Amado Coutinho São Paulo Brasil
# 81.33971291866028%...
# Requesting coordinates from Avenida General Valdomiro de Lima São Paulo Brasil
# 81.49920255183413%...
# Requesting coordinates from Rua Cesário Ramalho São Paulo Brasil
# 81.65869218500798%...
# Requesting coordinates from Avenida General Francisco Glicério Santos Brasil
# 81.81818181818181%...
# Requesting coordinates from Rua Dolzani Ricardo São José dos Campos Brasil
# 81.97767145135566%...
# Requesting coordinates from Rua Jerônima Dias São Paulo Brasil
# 82.13716108452951%...
# Requesting coordinates from Rua Porta do Prado São Paulo Brasil
# 82.29665071770334%...
# Requesting coordinates from Rua Pedro Carleto Netto Sertãozinho Brasil
# 82.45614035087719%...
# 82.61562998405104%...
# Requesting coordinates from Avenida Brasil Americana Brasil
# 82.77511961722487%...
# Requesting coordinates from Rua Cônego Demétrio Tatuí Brasil
# 82.93460925039872%...
# Requesting coordinates from Avenida Imirim São Paulo Brasil
# 83.09409888357257%...
# Requesting coordinates from Travessa Apeninos Santo André Brasil
# 83.2535885167464%...
# Requesting coordinates from Avenida Álvaro Ramos São Paulo Brasil
# 83.41307814992025%...
# Requesting coordinates from Rua Bahia Araçatuba Brasil
# 83.5725677830941%...
# Requesting coordinates from Avenida Portugal Mauá Brasil
# 83.73205741626795%...
# Requesting coordinates from Rua Cubatão São Paulo Brasil
# 83.89154704944178%...
# Requesting coordinates from Rua Minas Gerais São José do Rio Preto Brasil
# 84.05103668261563%...
# Requesting coordinates from Rua Guatemala Praia Grande Brasil
# 84.21052631578948%...
# Requesting coordinates from Rua Doutor Francisco Queiroz Guimarães Sumaré Brasil
# 84.37001594896331%...
# Requesting coordinates from Rua Alberto Callix São Paulo Brasil
# 84.52950558213716%...
# Requesting coordinates from Rodovia Santos Dumont Campinas Brasil
# 84.68899521531101%...
# Requesting coordinates from Rua João Zacharias Guarulhos Brasil
# 84.84848484848484%...
# Requesting coordinates from Avenida Nazaré São Paulo Brasil
# 85.00797448165869%...
# Requesting coordinates from Avenida das Nações Unidas São Paulo Brasil
# 85.16746411483254%...
# Requesting coordinates from Avenida Salgado Filho Guarulhos Brasil
# 85.32695374800637%...
# Requesting coordinates from Rua Marselhesa São Paulo Brasil
# 85.48644338118022%...
# Requesting coordinates from Rua Clélia São Paulo Brasil
# 85.64593301435407%...
# Requesting coordinates from Rua Cubatão São Paulo Brasil
# 85.8054226475279%...
# 85.96491228070175%...
# Requesting coordinates from Estrada de Itapecerica São Paulo Brasil
# 86.1244019138756%...
# Requesting coordinates from Alameda Campinas São Paulo Brasil
# 86.28389154704944%...
# Requesting coordinates from Avenida Santo Amaro São Paulo Brasil
# 86.44338118022328%...
# 86.60287081339713%...
# Requesting coordinates from Avenida Água Fria São Paulo Brasil
# 86.76236044657097%...
# Requesting coordinates from Avenida Água Fria São Paulo Brasil
# 86.92185007974481%...
# Requesting coordinates from Rua Padre Benedito de Camargo São Paulo Brasil
# 87.08133971291866%...
# Requesting coordinates from Avenida Paes de Barros São Paulo Brasil
# 87.24082934609251%...
# Requesting coordinates from Rua Doutor Edgard Magalhães Noronha São Paulo Brasil
# 87.40031897926634%...
# Requesting coordinates from Avenida Europa São Paulo Brasil
# 87.5598086124402%...
# Requesting coordinates from Rua Peixoto Gomide São Paulo Brasil
# 87.71929824561404%...
# 87.87878787878788%...
# Requesting coordinates from Avenida Nove de Julho São Paulo Brasil
# 88.03827751196172%...
# Requesting coordinates from Rua Cidade de Bagdá São Paulo Brasil
# 88.19776714513557%...
# Requesting coordinates from Travessa Açucena-do-Brejo São Paulo Brasil
# 88.3572567783094%...
# Requesting coordinates from Rua João Augusto Morais São Paulo Brasil
# 88.51674641148325%...
# Requesting coordinates from Rua José Oscar Abreu Sampaio São Paulo Brasil
# 88.6762360446571%...
# Requesting coordinates from Rua Ulisses Cruz São Paulo Brasil
# 88.83572567783094%...
# Requesting coordinates from Rua Bom Sucesso São Paulo Brasil
# 88.99521531100478%...
# Requesting coordinates from Rua Voluntários da Pátria São Paulo Brasil
# 89.15470494417863%...
# Requesting coordinates from Rua Maestro Cardim São Paulo Brasil
# 89.31419457735247%...
# Requesting coordinates from Rua Estela São Paulo Brasil
# 89.47368421052632%...
# Requesting coordinates from Avenida do Jangadeiro São Paulo Brasil
# 89.63317384370016%...
# Requesting coordinates from Avenida Engenho Novo São Paulo Brasil
# 89.792663476874%...
# Requesting coordinates from Avenida Rebouças São Paulo Brasil
# 89.95215311004785%...
# Requesting coordinates from Avenida Ibirapuera São Paulo Brasil
# 90.1116427432217%...
# Requesting coordinates from Rua Serra do Roncador São José dos Campos Brasil
# 90.27113237639553%...
# Requesting coordinates from Avenida Doutor Alberto Benedetti Santo André Brasil
# 90.43062200956938%...
# Requesting coordinates from Rua Maestro Azevedo Mogi Mirim Brasil
# 90.59011164274322%...
# Requesting coordinates from Avenida Engenheiro Luiz Edmundo Carrijo Coube Bauru Brasil
# 90.74960127591707%...
# Requesting coordinates from Estrada Tenente Marques Santana de Parnaíba Brasil
# 90.9090909090909%...
# Requesting coordinates from Rua Doutor Ângelo Vita Guarulhos Brasil
# 91.06858054226475%...
# Requesting coordinates from Avenida Cruzeiro do Sul São Paulo Brasil
# 91.2280701754386%...
# Requesting coordinates from Avenida Francisco Rodrigues São Paulo Brasil
# 91.38755980861244%...
# Requesting coordinates from Avenida Egisto Sicchieri Sertãozinho Brasil
# 91.54704944178629%...
# Requesting coordinates from Avenida de Cillo Americana Brasil
# 91.70653907496013%...
# Requesting coordinates from Avenida Brigadeiro Luís Antônio São Paulo Brasil
# 91.86602870813397%...
# Requesting coordinates from Rua Hannemann São Paulo Brasil
# 92.02551834130782%...
# Requesting coordinates from Alameda Gabriel Monteiro da Silva São Paulo Brasil
# 92.18500797448166%...
# Requesting coordinates from Rua Bandeira de Aracambi São Paulo Brasil
# 92.3444976076555%...
# Requesting coordinates from Avenida Mandaqui São Paulo Brasil
# 92.50398724082935%...
# Requesting coordinates from Rua Coronel Conrado Siqueira Campos São Paulo Brasil
# 92.6634768740032%...
# Requesting coordinates from Rua Pedroso Alvarenga São Paulo Brasil
# 92.82296650717703%...
# Requesting coordinates from Rua Catão São Paulo Brasil
# 92.98245614035088%...
# Requesting coordinates from Avenida Vereador Abel Ferreira São Paulo Brasil
# 93.14194577352472%...
# Requesting coordinates from Avenida Angélica São Paulo Brasil
# 93.30143540669856%...
# Requesting coordinates from Rua Voluntários da Pátria São Paulo Brasil
# 93.46092503987241%...
# Requesting coordinates from Avenida Tiradentes Itu Brasil
# 93.62041467304626%...
# Requesting coordinates from Avenida dos Metalúrgicos São Paulo Brasil
# 93.77990430622009%...
# 93.93939393939394%...
# Requesting coordinates from Rua Emílio Mallet São Paulo Brasil
# 94.09888357256779%...
# Requesting coordinates from Rua Carlos Petit São Paulo Brasil
# 94.25837320574162%...
# Requesting coordinates from Rua Barão de Monte Santo Mococa Brasil
# 94.41786283891547%...
# 94.57735247208932%...
# Requesting coordinates from Rua Artur Nunes da Silva São Paulo Brasil
# 94.73684210526316%...
# Requesting coordinates from Avenida Miguel Ignácio Curi São Paulo Brasil
# 94.896331738437%...
# Requesting coordinates from Rua José Pisciotta Valinhos Brasil
# 95.05582137161085%...
# Requesting coordinates from Rua Ezequiel Freire São Paulo Brasil
# 95.2153110047847%...
# Requesting coordinates from Rua Visconde de Inhaúma Ribeirão Preto Brasil
# 95.37480063795853%...
# Requesting coordinates from Rua Dom Bosco Lorena Brasil
# 95.53429027113238%...
# Requesting coordinates from Avenida Conselheiro Nébias Santos Brasil
# 95.69377990430623%...
# Requesting coordinates from Avenida Ester Cosmópolis Brasil
# 95.85326953748006%...
# Requesting coordinates from Rua Engenheiro Francisco Bicalho São Paulo Brasil
# 96.01275917065391%...
# Requesting coordinates from Avenida Professor Francisco Morato São Paulo Brasil
# 96.17224880382776%...
# Requesting coordinates from Avenida Professor Celestino Bourroul São Paulo Brasil
# 96.33173843700159%...
# Requesting coordinates from Rua Barão de Mauá Guarulhos Brasil
# 96.49122807017544%...
# Requesting coordinates from Rua Tomoichi Shimizu São Paulo Brasil
# 96.65071770334929%...
# Requesting coordinates from Rua Dom Manuel D'Elboux São Paulo Brasil
# 96.81020733652312%...
# Requesting coordinates from Rua Almirante Pereira Guimarães São Paulo Brasil
# 96.96969696969697%...
# Requesting coordinates from Rua Quinze de Novembro Tatuí Brasil
# 97.12918660287082%...
# Requesting coordinates from Rua Filipe Cardoso São Paulo Brasil
# 97.28867623604465%...
# Requesting coordinates from Rua Texas São Paulo Brasil
# 97.4481658692185%...
# Requesting coordinates from Rua General Sócrates São Paulo Brasil
# 97.60765550239235%...
# Requesting coordinates from Rua José Cianciarulo Osasco Brasil
# 97.76714513556618%...
# Requesting coordinates from Avenida Lavandisca São Paulo Brasil
# 97.92663476874003%...
# Requesting coordinates from Rua Manoel Antônio Pinto São Paulo Brasil
# 98.08612440191388%...
# Requesting coordinates from Rua Zacarias de Gois São Paulo Brasil
# 98.24561403508773%...
# Requesting coordinates from Rua Padre Estevão Pernet São Paulo Brasil
# 98.40510366826156%...
# Requesting coordinates from Rua Maciel Monteiro São Paulo Brasil
# 98.56459330143541%...
# Requesting coordinates from Rua Doutor Teófilo Ribeiro de Andrade São João da Boa Vista Brasil
# 98.72408293460926%...
# Requesting coordinates from Avenida João Dias São Paulo Brasil
# 98.88357256778309%...
# Requesting coordinates from Rua Doutor Orlando Zamiti Mammana São Paulo Brasil
# 99.04306220095694%...
# 99.20255183413079%...
# Requesting coordinates from Avenida Presidente Kennedy Diadema Brasil
# 99.36204146730462%...
# Requesting coordinates from Rua Jorge Maraccini Ponfílio São Paulo Brasil
# 99.52153110047847%...
# Requesting coordinates from Avenida Tiradentes Taubaté Brasil
# 99.68102073365232%...
# Requesting coordinates from Rua Maestro Cardim 769 São Paulo Brasil
# 99.84051036682615%...

# %% [markdown]
# > Using the cep_to_coords function we were able to fill **78%** of the missing coordinates!
#
# ### Compiling the final CEP table
#
# To complete the data preparation, we need to take our filled coordinates and replace the NaNs on the death records table.

# %%
unique_merged["CO_CEP"] = (
    unique_merged["CO_CEP"].astype(str).apply(lambda x: x.zfill(8))
)
# unfortunately we didn't fill all coordinates, let's drop them
missing_coords = missing_coords.drop(columns=["NU_LATITUDE", "NU_LONGITUDE"]).dropna()
# joining the datasets
full_table = unique_merged.merge(missing_coords, on="CO_CEP", how="left")
# filling the missing data
full_table["lat"] = full_table.apply(
    lambda x: x["lat"] if pd.isnull(x["NU_LATITUDE"]) else x["NU_LATITUDE"], axis=1
)
full_table["lon"] = full_table.apply(
    lambda x: x["lon"] if pd.isnull(x["NU_LONGITUDE"]) else x["NU_LONGITUDE"], axis=1
)
# compiling the CEP final table
full_table = (
    full_table.drop(columns=["NU_LATITUDE", "NU_LONGITUDE", "CODESTAB_y"])
    .dropna()
    .rename(columns={"CODESTAB_x": "CODESTAB"})
    .reset_index(drop=True)
)

# %% [markdown]
# ### Merging the facilities back to the death records dataframe and cleaning the data

# %%
df_enriched = df.merge(full_table, on="CODESTAB")
df_enriched["HORAOBITO"] = pd.to_numeric(
    df_enriched["HORAOBITO"], downcast="integer", errors="coerce"
)
df_enriched = df_enriched.dropna()
df_enriched["DTOBITO"] = df_enriched["DTOBITO"].astype(str).apply(lambda x: x.zfill(8))
df_enriched["HORAOBITO"] = (
    df_enriched["HORAOBITO"].astype(int).astype(str).apply(lambda x: x.zfill(4))
)
# Creating a timestamp column with both date and hour of death
df_enriched["DATA"] = df_enriched["DTOBITO"] + " " + df_enriched["HORAOBITO"]
df_enriched["DATA"] = pd.to_datetime(
    df_enriched["DATA"], format="%d%m%Y %H%M", errors="coerce"
)
df_enriched = df_enriched.dropna()
df_enriched["NUMERODO"] = df_enriched["NUMERODO"].astype(str)

df_enriched["lat"] = (
    df_enriched["lat"].astype(str).str.replace(",", ".", regex=False).astype(float)
)

df_enriched["lon"] = (
    df_enriched["lon"].astype(str).str.replace(",", ".", regex=False).astype(float)
)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.

# %% [markdown]
# ### Saving to a .parquet file

# %%
df_enriched.to_parquet("../data/clean/dataset.parquet.gzip", compression="gzip", index=False)

# %% [markdown]
# ## Creating the app using the Uber pickups example
#
# Streamlit according to the website is
# > “The fastest way to build custom ML tools”.
#
# It is indeed a bold statement, but what sold me on it was the sentence on the subtitle:
# > “So you can stop spending time on frontend development and get back to what you do best.”.
#
# For this experiment, we are going to spend even less time on frontend development by using an example gently posted by the Streamlit team (https://github.com/streamlit/demo-uber-nyc-pickups). The demo presents the Uber pickups on New York City by hour. Our goal here is to replace pickups with deaths registered on SIM and New York City with the state of São Paulo.
#
# There are only a few things we need to change in the code to adapt the application to our use.
#
# ### Clone the repository
# ```bash
# git clone https://github.com/streamlit/demo-uber-nyc-pickups.git
# cd demo-uber-nyc-pickups
# ```
#
# ### Open app.py on your favorite text editor and change the following lines (commented here)

# %%
# OLD -> DATE_TIME = "date/time"
# NEW -> DATE_TIME = "data"

# OLD -> data = pd.read_csv(DATA_URL, nrows=nrows)
# NEW -> data = pd.read_parquet("../data/clean/dataset.parquet.gzip")

# %% [markdown]
# For cosmetic purposes you may also change the title and other specific references
#
# ### Install streamlit
# ```bash
# pip install streamlit
# ```
#
# ### Run the app
# ```bash
# streamlit run app.py
# ```
#
# ![terminal_streamlit](../assets/terminal_streamlit.png)
#
# Voilà! This command will automatically open the app on your browser (port 8051 by default).
#
# # Conclusion
# This is a very simple project that shows some amazing libraries that are being developed lately for Machine Learning applications. Although we didn't used any complex techniques here, we covered an interesting part of what a data scientist do. Data ingestion, cleaning, enriching and finally visualization.
#
# I hope you learned something from this and I encourage you to play around with Streamlit, it's definitely amazing!
